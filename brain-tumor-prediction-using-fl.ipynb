# %% [markdown]
# <a href="https://www.kaggle.com/code/prabujayant/brain-tumor-prediction-using-fl?scriptVersionId=166666014" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# For Data Processing
import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image, ImageEnhance

# For ML Models
from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras.losses import *
from tensorflow.keras.models import *
from tensorflow.keras.metrics import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.applications import *
from tensorflow.keras.preprocessing.image import load_img

# For Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Miscellaneous
from tqdm import tqdm
import os
import random
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
train_dir = '/kaggle/input/brain-tumor-mri-dataset/Training/'
test_dir = '/kaggle/input/brain-tumor-mri-dataset/Testing/'

train_paths = []
train_labels = []

for label in os.listdir(train_dir):
    for image in os.listdir(train_dir+label):
        train_paths.append(train_dir+label+'/'+image)
        train_labels.append(label)

train_paths, train_labels = shuffle(train_paths, train_labels)

# %%
plt.figure(figsize=(14,6))
colors = ['#F6F7C1', '#BEF0CB', '#D1FFF3', '#C1AEFC']
plt.rcParams.update({'font.size': 20})
plt.pie([len([x for x in train_labels if x=='pituitary']),
         len([x for x in train_labels if x=='notumor']),
         len([x for x in train_labels if x=='meningioma']),
         len([x for x in train_labels if x=='glioma'])],
        labels=['pituitary','notumor', 'meningioma', 'glioma'],
        colors=colors, autopct='%.1f%%', explode=(0.015,0.015,0.015,0.015),
        startangle=30);

# %%
test_paths = []
test_labels = []

for label in os.listdir(test_dir):
    for image in os.listdir(test_dir+label):
        test_paths.append(test_dir+label+'/'+image)
        test_labels.append(label)

test_paths, test_labels = shuffle(test_paths, test_labels)

# %%
plt.figure(figsize=(14,6))
colors = ['#BEF0CB', '#C1AEFC']
plt.rcParams.update({'font.size': 20})
plt.pie([len(train_labels), len(test_labels)],
        labels=['Train','Test'],
        colors=colors, autopct='%.1f%%', explode=(0.05,0),
        startangle=30);

# %%
def augment_image(image):
    image = Image.fromarray(np.uint8(image))
    image = ImageEnhance.Brightness(image).enhance(random.uniform(0.8,1.2))
    image = ImageEnhance.Contrast(image).enhance(random.uniform(0.8,1.2))
    image = np.array(image)/255.0
    return image

# %%
IMAGE_SIZE = 128

def open_images(paths):
    '''
    Given a list of paths to images, this function returns the images as arrays (after augmenting them)
    '''
    images = []
    for path in paths:
        image = load_img(path, target_size=(IMAGE_SIZE,IMAGE_SIZE))
        image = augment_image(image)
        images.append(image)
    return np.array(images)

images = open_images(train_paths[50:59])
labels = train_labels[50:59]
fig = plt.figure(figsize=(12, 6))
for x in range(1, 9):
    fig.add_subplot(2, 4, x)
    plt.axis('off')
    plt.title(labels[x])
    plt.imshow(images[x])
plt.rcParams.update({'font.size': 20})
plt.show()

# %%
unique_labels = os.listdir(train_dir)

def encode_label(labels):
    encoded = []
    for x in labels:
        encoded.append(unique_labels.index(x))
    return np.array(encoded)

def decode_label(labels):
    decoded = []
    for x in labels:
        decoded.append(unique_labels[x])
    return np.array(decoded)

def datagen(paths, labels, batch_size=12, epochs=1):
    for _ in range(epochs):
        for x in range(0, len(paths), batch_size):
            batch_paths = paths[x:x+batch_size]
            batch_images = open_images(batch_paths)
            batch_labels = labels[x:x+batch_size]
            batch_labels = encode_label(batch_labels)
            yield batch_images, batch_labels

# %%
base_model = VGG16(input_shape=(IMAGE_SIZE,IMAGE_SIZE,3), include_top=False, weights='imagenet')
# Set all layers to non-trainable
for layer in base_model.layers:
    layer.trainable = False
# Set the last vgg block to trainable
base_model.layers[-2].trainable = True
base_model.layers[-3].trainable = True
base_model.layers[-4].trainable = True

model = Sequential()
model.add(Input(shape=(IMAGE_SIZE,IMAGE_SIZE,3)))
model.add(base_model)
model.add(Flatten())
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(len(unique_labels), activation='softmax'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dropout (Dropout)           (None, 8192)              0
#
#  dense (Dense)               (None, 128)               1048704
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 15763908 (60.13 MB)
# Trainable params: 8128644 (31.01 MB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
model.compile(optimizer=Adam(learning_rate=0.0001),
             loss='sparse_categorical_crossentropy',
             metrics=['sparse_categorical_accuracy'])

# %%
batch_size = 25
steps = int(len(train_paths)/batch_size)
epochs = 15
history = model.fit(datagen(train_paths, train_labels, batch_size=batch_size, epochs=epochs),
                    epochs=epochs, steps_per_epoch=steps)
# Out:
# Epoch 1/15
# 228/228 [==============================] - 58s 223ms/step - loss: 0.4701 - sparse_categorical_accuracy: 0.8214
# Epoch 2/15
# 228/228 [==============================] - 23s 95ms/step - loss: 0.2275 - sparse_categorical_accuracy: 0.9193
# Epoch 3/15
# 228/228 [==============================] - 21s 94ms/step - loss: 0.1512 - sparse_categorical_accuracy: 0.9399
# Epoch 4/15
# 228/228 [==============================] - 21s 94ms/step - loss: 0.1052 - sparse_categorical_accuracy: 0.9618
# Epoch 5/15
# 228/228 [==============================] - 21s 94ms/step - loss: 0.0817 - sparse_categorical_accuracy: 0.9715
# Epoch 6/15
# 228/228 [==============================] - 21s 91ms/step - loss: 0.0752 - sparse_categorical_accuracy: 0.9727
# Epoch 7/15
# 228/228 [==============================] - 22s 99ms/step - loss: 0.0447 - sparse_categorical_accuracy: 0.9859
# Epoch 8/15
# 228/228 [==============================] - 21s 93ms/step - loss: 0.0414 - sparse_categorical_accuracy: 0.9873
# Epoch 9/15
# 228/228 [==============================] - 21s 94ms/step - loss: 0.0253 - sparse_categorical_accuracy: 0.9912
# Epoch 10/15
# 228/228 [==============================] - 21s 94ms/step - loss: 0.0277 - sparse_categorical_accuracy: 0.9902
# Epoch 11/15
# 228/228 [==============================] - 21s 93ms/step - loss: 0.0314 - sparse_categorical_accuracy: 0.9903
# Epoch 12/15
# 228/228 [==============================] - 21s 93ms/step - loss: 0.0416 - sparse_categorical_accuracy: 0.9856
# Epoch 13/15
# 228/228 [==============================] - 21s 94ms/step - loss: 0.0491 - sparse_categorical_accuracy: 0.9822
# Epoch 14/15
# 228/228 [==============================] - 21s 93ms/step - loss: 0.0069 - sparse_categorical_accuracy: 0.9977
# Epoch 15/15
# 228/228 [==============================] - 21s 94ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9937

# %%
#Federated Learning Based transfer Learning enabled VGG-16 Model
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the number of clients and the number of training rounds
NUM_CLIENTS = 10
NUM_ROUNDS = 3


# Define the clients and their data
clients = []
for i in range(NUM_CLIENTS):
    client_data = train_paths[i * (len(train_paths) // NUM_CLIENTS):(i + 1) * (len(train_paths) // NUM_CLIENTS)]
    client_labels = train_labels[i * (len(train_labels) // NUM_CLIENTS):(i + 1) * (len(train_labels) // NUM_CLIENTS)]
    clients.append((client_data, client_labels))

# Federated learning loop
for round_num in range(NUM_ROUNDS):

    # Select clients
    selected_client_indices = np.random.choice(len(clients), size=int(NUM_CLIENTS * 0.5), replace=False)
    selected_clients = [clients[i] for i in selected_client_indices]

    # Transmit the global model to the selected clients
    for client in selected_clients:
        client_model = tf.keras.models.clone_model(model)
        client_model.set_weights(model.get_weights())
  
        # Compile the client model
        client_model.compile(optimizer=Adam(learning_rate=0.0001),
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy'])

        steps_per_epoch = int(len(client[0]) / 20)
        

        client_model.fit(datagen(client[0],client[1], batch_size=batch_size, epochs=epochs),
                         epochs=5, steps_per_epoch=steps_per_epoch)

        # Train locally
        steps_per_epoch = int(len(client[0]) / 20)

        # Aggregate the model
        new_weights = []
        for layer_index in range(len(model.get_weights())):
            new_layer_weights = np.mean([client_model.get_weights()[layer_index], model.get_weights()[layer_index]], axis=0)
            new_weights.append(new_layer_weights)
        model.set_weights(new_weights)

        
batch_size = 32
steps = int(len(test_paths)/batch_size)
y_pred = []
y_true = []
for x,y in tqdm(datagen(test_paths, test_labels, batch_size=batch_size, epochs=1), total=steps):
    pred = model.predict(x)
    pred = np.argmax(pred, axis=-1)
    for i in decode_label(pred):
        y_pred.append(i)
    for i in decode_label(y):
        y_true.append(i)

#     # Evaluate the global model
#     test_loss, test_acc = model.evaluate(test_paths, test_labels,)
#     print('Round {}: Test accuracy = {}'.format(round_num, test_acc))

# # Fine-tune the model
# model.fit(test_paths, test_labels, epochs=1, batch_size=32)

# Deploy the model
model.save('my_model.h5')
# Out:
# Epoch 1/5
# 28/28 [==============================] - 6s 138ms/step - loss: 0.0235 - sparse_categorical_accuracy: 0.9928
# Epoch 2/5
# 28/28 [==============================] - 3s 95ms/step - loss: 0.0159 - sparse_categorical_accuracy: 0.9928
# Epoch 3/5
# 28/28 [==============================] - 3s 103ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9957
# Epoch 4/5
# 28/28 [==============================] - 3s 95ms/step - loss: 0.0129 - sparse_categorical_accuracy: 0.9928
# Epoch 5/5
# 28/28 [==============================] - 3s 102ms/step - loss: 9.3214e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 1/5
# 28/28 [==============================] - 5s 89ms/step - loss: 0.0165 - sparse_categorical_accuracy: 0.9971
# Epoch 2/5
# 28/28 [==============================] - 3s 94ms/step - loss: 0.0025 - sparse_categorical_accuracy: 1.0000
# Epoch 3/5
# 28/28 [==============================] - 3s 90ms/step - loss: 0.0189 - sparse_categorical_accuracy: 0.9928
# Epoch 4/5
# 28/28 [==============================] - 3s 91ms/step - loss: 0.0273 - sparse_categorical_accuracy: 0.9943
# Epoch 5/5
# 28/28 [==============================] - 2s 88ms/step - loss: 0.0162 - sparse_categorical_accuracy: 0.9942
# Epoch 1/5
# 28/28 [==============================] - 5s 84ms/step - loss: 0.0129 - sparse_categorical_accuracy: 0.9928
# Epoch 2/5
# 28/28 [==============================] - 3s 94ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9928
# Epoch 3/5
# 28/28 [==============================] - 3s 97ms/step - loss: 0.0152 - sparse_categorical_accuracy: 0.9943
# Epoch 4/5
# 28/28 [==============================] - 3s 93ms/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000
# Epoch 5/5
# 28/28 [==============================] - 3s 94ms/step - loss: 1.1067e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 1/5
# 28/28 [==============================] - 5s 90ms/step - loss: 5.2309e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 2/5
# 28/28 [==============================] - 3s 98ms/step - loss: 0.1066 - sparse_categorical_accuracy: 0.9799
# Epoch 3/5
# 28/28 [==============================] - 3s 101ms/step - loss: 0.0405 - sparse_categorical_accuracy: 0.9914
# Epoch 4/5
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0077 - sparse_categorical_accuracy: 0.9943
# Epoch 5/5
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0108 - sparse_categorical_accuracy: 0.9942
# Epoch 1/5
# 28/28 [==============================] - 5s 90ms/step - loss: 0.0160 - sparse_categorical_accuracy: 0.9943
# Epoch 2/5
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0299 - sparse_categorical_accuracy: 0.9943
# Epoch 3/5
# 28/28 [==============================] - 3s 93ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9957
# Epoch 4/5
# 28/28 [==============================] - 3s 95ms/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9971
# Epoch 5/5
# 28/28 [==============================] - 3s 92ms/step - loss: 0.0119 - sparse_categorical_accuracy: 0.9957
# Epoch 1/5
# 28/28 [==============================] - 5s 89ms/step - loss: 0.0010 - sparse_categorical_accuracy: 1.0000
# Epoch 2/5
# 28/28 [==============================] - 3s 97ms/step - loss: 0.0423 - sparse_categorical_accuracy: 0.9914
# Epoch 3/5
# 28/28 [==============================] - 3s 93ms/step - loss: 0.0158 - sparse_categorical_accuracy: 0.9943
# Epoch 4/5
# 28/28 [==============================] - 3s 98ms/step - loss: 0.0150 - sparse_categorical_accuracy: 0.9957
# Epoch 5/5
# 28/28 [==============================] - 3s 111ms/step - loss: 0.0269 - sparse_categorical_accuracy: 0.9884
# Epoch 1/5
# 28/28 [==============================] - 5s 95ms/step - loss: 0.0099 - sparse_categorical_accuracy: 0.9971
# Epoch 2/5
# 28/28 [==============================] - 3s 97ms/step - loss: 0.0104 - sparse_categorical_accuracy: 0.9971
# Epoch 3/5
# 28/28 [==============================] - 3s 95ms/step - loss: 0.0149 - sparse_categorical_accuracy: 0.9943
# Epoch 4/5
# 28/28 [==============================] - 3s 99ms/step - loss: 0.0317 - sparse_categorical_accuracy: 0.9943
# Epoch 5/5
# 28/28 [==============================] - 3s 92ms/step - loss: 0.0086 - sparse_categorical_accuracy: 0.9986
# Epoch 1/5
# 28/28 [==============================] - 5s 89ms/step - loss: 0.0307 - sparse_categorical_accuracy: 0.9914
# Epoch 2/5
# 28/28 [==============================] - 3s 94ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9943
# Epoch 3/5
# 28/28 [==============================] - 3s 93ms/step - loss: 0.0275 - sparse_categorical_accuracy: 0.9914
# Epoch 4/5
# 28/28 [==============================] - 3s 92ms/step - loss: 0.0900 - sparse_categorical_accuracy: 0.9842
# Epoch 5/5
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0247 - sparse_categorical_accuracy: 0.9884
# Epoch 1/5
# 28/28 [==============================] - 5s 86ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9971
# Epoch 2/5
# 28/28 [==============================] - 3s 94ms/step - loss: 0.0113 - sparse_categorical_accuracy: 0.9957
# Epoch 3/5
# 28/28 [==============================] - 3s 92ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9986
# Epoch 4/5
# 28/28 [==============================] - 3s 93ms/step - loss: 0.0972 - sparse_categorical_accuracy: 0.9871
# Epoch 5/5
# 28/28 [==============================] - 3s 103ms/step - loss: 0.0459 - sparse_categorical_accuracy: 0.9899
# Epoch 1/5
# 28/28 [==============================] - 5s 88ms/step - loss: 0.0197 - sparse_categorical_accuracy: 0.9957
# Epoch 2/5
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0262 - sparse_categorical_accuracy: 0.9928
# Epoch 3/5
# 28/28 [==============================] - 3s 94ms/step - loss: 0.0272 - sparse_categorical_accuracy: 0.9914
# Epoch 4/5
# 28/28 [==============================] - 3s 95ms/step - loss: 0.0459 - sparse_categorical_accuracy: 0.9899
# Epoch 5/5
# 28/28 [==============================] - 3s 98ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9971
# Epoch 1/5
# 28/28 [==============================] - 5s 87ms/step - loss: 0.0122 - sparse_categorical_accuracy: 0.9943
# Epoch 2/5
# 28/28 [==============================] - 3s 94ms/step - loss: 0.0297 - sparse_categorical_accuracy: 0.9928
# Epoch 3/5
# 28/28 [==============================] - 3s 101ms/step - loss: 0.0024 - sparse_categorical_accuracy: 1.0000
# Epoch 4/5
# 28/28 [==============================] - 3s 98ms/step - loss: 8.0906e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 5/5
# 28/28 [==============================] - 3s 101ms/step - loss: 2.3174e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 1/5
# 28/28 [==============================] - 5s 102ms/step - loss: 0.0134 - sparse_categorical_accuracy: 0.9971
# Epoch 2/5
# 28/28 [==============================] - 3s 95ms/step - loss: 0.0400 - sparse_categorical_accuracy: 0.9885
# Epoch 3/5
# 28/28 [==============================] - 3s 114ms/step - loss: 0.0340 - sparse_categorical_accuracy: 0.9899
# Epoch 4/5
# 28/28 [==============================] - 5s 170ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9986
# Epoch 5/5
# 28/28 [==============================] - 6s 222ms/step - loss: 6.6268e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 1/5
# 28/28 [==============================] - 5s 88ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9957
# Epoch 2/5
# 28/28 [==============================] - 3s 98ms/step - loss: 1.5767e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 3/5
# 28/28 [==============================] - 3s 101ms/step - loss: 0.1394 - sparse_categorical_accuracy: 0.9799
# Epoch 4/5
# 28/28 [==============================] - 3s 90ms/step - loss: 0.0716 - sparse_categorical_accuracy: 0.9899
# Epoch 5/5
# 28/28 [==============================] - 3s 90ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9986
# Epoch 1/5
# 28/28 [==============================] - 5s 89ms/step - loss: 0.0103 - sparse_categorical_accuracy: 0.9971
# Epoch 2/5
# 28/28 [==============================] - 3s 93ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9986
# Epoch 3/5
# 28/28 [==============================] - 3s 94ms/step - loss: 0.0242 - sparse_categorical_accuracy: 0.9943
# Epoch 4/5
# 28/28 [==============================] - 3s 94ms/step - loss: 0.0638 - sparse_categorical_accuracy: 0.9914
# Epoch 5/5
# 28/28 [==============================] - 3s 98ms/step - loss: 0.0274 - sparse_categorical_accuracy: 0.9971
# Epoch 1/5
# 28/28 [==============================] - 5s 89ms/step - loss: 0.0060 - sparse_categorical_accuracy: 0.9986
# Epoch 2/5
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0110 - sparse_categorical_accuracy: 0.9971
# Epoch 3/5
# 28/28 [==============================] - 3s 95ms/step - loss: 1.9895e-05 - sparse_categorical_accuracy: 1.0000
# Epoch 4/5
# 28/28 [==============================] - 3s 100ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9971
# Epoch 5/5
# 28/28 [==============================] - 3s 96ms/step - loss: 7.3034e-04 - sparse_categorical_accuracy: 1.0000
#   0%|          | 0/40 [00:00<?, ?it/s]
# 1/1 [==============================] - 2s 2s/step
#   2%|▎         | 1/40 [00:02<01:41,  2.60s/it]
# 1/1 [==============================] - 0s 23ms/step
#   5%|▌         | 2/40 [00:03<00:50,  1.33s/it]
# 1/1 [==============================] - 0s 28ms/step
#   8%|▊         | 3/40 [00:03<00:35,  1.05it/s]
# 1/1 [==============================] - 0s 27ms/step
#  10%|█         | 4/40 [00:04<00:27,  1.32it/s]
# 1/1 [==============================] - 0s 24ms/step
#  12%|█▎        | 5/40 [00:04<00:23,  1.49it/s]
# 1/1 [==============================] - 0s 24ms/step
#  15%|█▌        | 6/40 [00:04<00:20,  1.68it/s]
# 1/1 [==============================] - 0s 24ms/step
#  18%|█▊        | 7/40 [00:05<00:17,  1.85it/s]
# 1/1 [==============================] - 0s 24ms/step
#  20%|██        | 8/40 [00:05<00:16,  1.95it/s]
# 1/1 [==============================] - 0s 21ms/step
#  22%|██▎       | 9/40 [00:06<00:14,  2.09it/s]
# 1/1 [==============================] - 0s 23ms/step
#  25%|██▌       | 10/40 [00:06<00:14,  2.08it/s]
# 1/1 [==============================] - 0s 26ms/step
#  28%|██▊       | 11/40 [00:07<00:13,  2.11it/s]
# 1/1 [==============================] - 0s 23ms/step
#  30%|███       | 12/40 [00:07<00:13,  2.07it/s]
# 1/1 [==============================] - 0s 22ms/step
#  32%|███▎      | 13/40 [00:08<00:13,  2.03it/s]
# 1/1 [==============================] - 0s 23ms/step
#  35%|███▌      | 14/40 [00:08<00:13,  1.98it/s]
# 1/1 [==============================] - 0s 22ms/step
#  38%|███▊      | 15/40 [00:09<00:12,  2.02it/s]
# 1/1 [==============================] - 0s 25ms/step
#  40%|████      | 16/40 [00:09<00:11,  2.04it/s]
# 1/1 [==============================] - 0s 30ms/step
#  42%|████▎     | 17/40 [00:10<00:11,  2.07it/s]
# 1/1 [==============================] - 0s 22ms/step
#  45%|████▌     | 18/40 [00:10<00:10,  2.07it/s]
# 1/1 [==============================] - 0s 23ms/step
#  48%|████▊     | 19/40 [00:11<00:10,  2.04it/s]
# 1/1 [==============================] - 0s 27ms/step
#  50%|█████     | 20/40 [00:11<00:09,  2.05it/s]
# 1/1 [==============================] - 0s 25ms/step
#  52%|█████▎    | 21/40 [00:12<00:09,  2.04it/s]
# 1/1 [==============================] - 0s 23ms/step
#  55%|█████▌    | 22/40 [00:12<00:08,  2.09it/s]
# 1/1 [==============================] - 0s 22ms/step
#  57%|█████▊    | 23/40 [00:13<00:07,  2.13it/s]
# 1/1 [==============================] - 0s 23ms/step
#  60%|██████    | 24/40 [00:13<00:07,  2.15it/s]
# 1/1 [==============================] - 0s 23ms/step
#  62%|██████▎   | 25/40 [00:13<00:07,  2.12it/s]
# 1/1 [==============================] - 0s 25ms/step
#  65%|██████▌   | 26/40 [00:14<00:06,  2.17it/s]
# 1/1 [==============================] - 0s 28ms/step
#  68%|██████▊   | 27/40 [00:14<00:06,  2.11it/s]
# 1/1 [==============================] - 0s 26ms/step
#  70%|███████   | 28/40 [00:15<00:05,  2.15it/s]
# 1/1 [==============================] - 0s 26ms/step
#  72%|███████▎  | 29/40 [00:15<00:05,  2.11it/s]
# 1/1 [==============================] - 0s 23ms/step
#  75%|███████▌  | 30/40 [00:16<00:04,  2.15it/s]
# 1/1 [==============================] - 0s 25ms/step
#  78%|███████▊  | 31/40 [00:16<00:04,  2.13it/s]
# 1/1 [==============================] - 0s 26ms/step
#  80%|████████  | 32/40 [00:17<00:03,  2.06it/s]
# 1/1 [==============================] - 0s 22ms/step
#  82%|████████▎ | 33/40 [00:17<00:03,  2.11it/s]
# 1/1 [==============================] - 0s 23ms/step
#  85%|████████▌ | 34/40 [00:18<00:02,  2.14it/s]
# 1/1 [==============================] - 0s 26ms/step
#  88%|████████▊ | 35/40 [00:18<00:02,  2.07it/s]
# 1/1 [==============================] - 0s 22ms/step
#  90%|█████████ | 36/40 [00:19<00:01,  2.01it/s]
# 1/1 [==============================] - 0s 23ms/step
#  92%|█████████▎| 37/40 [00:19<00:01,  2.00it/s]
# 1/1 [==============================] - 0s 26ms/step
#  95%|█████████▌| 38/40 [00:20<00:00,  2.01it/s]
# 1/1 [==============================] - 0s 22ms/step
#  98%|█████████▊| 39/40 [00:20<00:00,  2.05it/s]
# 1/1 [==============================] - 0s 21ms/step
# 100%|██████████| 40/40 [00:21<00:00,  2.07it/s]
# 1/1 [==============================] - 2s 2s/step
# 41it [00:23,  1.73it/s]
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       glioma       0.98      0.96      0.97       300
#   meningioma       0.95      0.94      0.95       306
#      notumor       0.99      1.00      1.00       405
#    pituitary       0.97      0.99      0.98       300
#
#     accuracy                           0.98      1311
#    macro avg       0.97      0.97      0.97      1311
# weighted avg       0.98      0.98      0.98      1311

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np




cm = confusion_matrix(y_true, y_pred)

# Define the font size
font_size = 20

# Plot the confusion matrix
plt.figure(figsize=(8,8))
sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", xticklabels=unique_labels, yticklabels=unique_labels, annot_kws={"fontsize": font_size}, cbar=False)
plt.xlabel("Predicted Label", fontsize=font_size)
plt.ylabel("True Label", fontsize=font_size)
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size, rotation=0)
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate incorrect predictions
incorrect_predictions = len(y_true) - np.sum(y_pred == y_true)

# Create labels and counts for the pie chart
labels = ['Correct Predictions', 'Incorrect Predictions']
counts = [len(y_true) - incorrect_predictions, incorrect_predictions]

# Define colors for the pie chart
colors = ['#BEF0CB', '#FF9999']

# Create pie chart
plt.figure(figsize=(8, 6))
plt.pie(counts, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Overall Accuracy')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
batch_size = 32  # Define batch size for evaluation
steps = int(len(test_paths) / batch_size)  # Calculate steps per epoch
y_pred = []  # Initialize list to store predicted labels
y_true = []  # Initialize list to store true labels

# Iterate over batches of test data
for x_batch, y_batch in datagen(test_paths, test_labels, batch_size=batch_size, epochs=1):
    # Predict labels for the current batch
    batch_pred = model.predict(x_batch)
    batch_pred = np.argmax(batch_pred, axis=-1)
    
    # Append predicted and true labels to the lists
    y_pred.extend(batch_pred)
    y_true.extend(y_batch)

# Convert lists to numpy arrays
y_pred = np.array(y_pred)
y_true = np.array(y_true)

# Calculate overall accuracy
overall_accuracy = np.mean(y_pred == y_true)

print("Overall Accuracy:", overall_accuracy)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Overall Accuracy: 0.9740655987795576

# %%
from tensorflow.keras.utils import plot_model

# Plot the model architecture
plot_model(model, to_file='model_diagram.png', show_shapes=True)
